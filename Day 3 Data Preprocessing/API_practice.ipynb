# %% [markdown]
# **Using kaggle API to import large datasets**
# - TO use kaggle API, create account on kaggle with same email as google colab.
# - Verify the account phone no.
# - create an API key, Save that json file
# - upload the kaggle.json file to the google colab current working directory
# - use ! before system commands

# %%
! pip install kaggle

# %%
# Path configuration of kaggle.json file
! mkdir -p ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# APi to fetch dataset from kaggle
! kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
# 100% 2.27G/2.27G [00:27<00:00, 114MB/s]
# 100% 2.27G/2.27G [00:27<00:00, 89.5MB/s]

# %%
# extract the above downloaded dataset

from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
 # Now the extracted dataset can be used in pandas DataFrame and other things can be done.
import pandas as pd
df = pd.read_csv('/content/train.csv')
df.desc()
