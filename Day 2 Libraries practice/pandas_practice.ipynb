# %% [markdown]
# Pandas
# * For Data Processing and Analysis
#
# Pandas Data Frame
# * 2D Tabular Data Structure with labelled axes(rows and columns)

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing # california house price dataset
from sklearn.datasets import fetch_openml

import numpy as np

# %%
housing = fetch_california_housing()

housing = fetch_openml(name="house_prices", as_frame=True)

type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing)
# Out:
# {'data':         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Creating a Data Frame from the dataset
# This way, no extra info needs to be dealt with
housingdf = pd.DataFrame(housing.data , columns = housing.feature_names)

# %%
housingdf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
print(housingdf.shape)
print(type(housingdf))
# Out:
# (1460, 80)
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv('diabetes.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Exporting Data Frame to csv and excel file
# housingdf.to_csv('california.csv') 
# housingdf.to_excel('california.excel')

# %%
randomDf = pd.DataFrame(np.random.randint(1,10,(10,5)))
randomDf
# Out:
#    0  1  2  3  4
# 0  1  9  1  2  9
# 1  3  5  8  2  5
# 2  3  6  8  1  7
# 3  5  5  4  2  4
# 4  2  5  7  1  9
# 5  7  5  3  6  6
# 6  6  7  1  8  6
# 7  2  9  5  3  3
# 8  8  2  8  2  4
# 9  5  3  1  1  3

# %%
randomDf.shape
# Out:
# (10, 5)

# %%
housingdf.shape
# Out:
# (1460, 80)

# %%
randomDf.head()
# Out:
#    0  1  2  3  4
# 0  1  9  1  2  9
# 1  3  5  8  2  5
# 2  3  6  8  1  7
# 3  5  5  4  2  4
# 4  2  5  7  1  9

# %%
randomDf.tail()
# Out:
#    0  1  2  3  4
# 5  7  5  3  6  6
# 6  6  7  1  8  6
# 7  2  9  5  3  3
# 8  8  2  8  2  4
# 9  5  3  1  1  3

# %%
randomDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     int32
#  1   1       10 non-null     int32
#  2   2       10 non-null     int32
#  3   3       10 non-null     int32
#  4   4       10 non-null     int32
# dtypes: int32(5)
# memory usage: 332.0 bytes

# %%
# Diabetes DataFrame

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.groupby('Outcome').mean() #Average values
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df.std() #Standard Deviation
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
df.describe() # All Statistical Measures in one command
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Adding column to dataframe
randomDf['New Column'] = [i for i in range(1,11)]
randomDf
# Out:
#    0  1  2  3  4  New Column
# 0  1  9  1  2  9           1
# 1  3  5  8  2  5           2
# 2  3  6  8  1  7           3
# 3  5  5  4  2  4           4
# 4  2  5  7  1  9           5
# 5  7  5  3  6  6           6
# 6  6  7  1  8  6           7
# 7  2  9  5  3  3           8
# 8  8  2  8  2  4           9
# 9  5  3  1  1  3          10

# %%
# Remove row by index
housingdf.drop(index= 0, axis=0)


# axis=0 means row axis=1 means column
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Remove column by index
housingdf.drop(columns='MSSubClass', axis=1)
# Out:
#         Id MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0        1       RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1        2       RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2        3       RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3        4       RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4        5       RL         84.0    14260   Pave   NaN      IR1         Lvl
# ...    ...      ...          ...      ...    ...   ...      ...         ...
# 1455  1456       RL         62.0     7917   Pave   NaN      Reg         Lvl
# 1456  1457       RL         85.0    13175   Pave   NaN      Reg         Lvl
# 1457  1458       RL         66.0     9042   Pave   NaN      Reg         Lvl
# 1458  1459       RL         68.0     9717   Pave   NaN      Reg         Lvl
# 1459  1460       RL         75.0     9937   Pave   NaN      Reg         Lvl
#
# ...

# %%
housingdf.iloc[2] # Data of 2nd index row
# Out:
# Id                    3
# MSSubClass           60
# MSZoning             RL
# LotFrontage        68.0
# LotArea           11250
#                   ...
# MiscVal               0
# MoSold                9
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# Name: 2, Length: 80, dtype: object

# %%
housingdf.iloc[:,1] # print Column index 1
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %% [markdown]
# Correlation
#
# * positive means if value of a increases then value of b also increases
# * negative means if value of a increases then value of b decreases

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...
